# %% [markdown]
# # Pandas Quick Demo
# Load a CSV and show basic stats.

# %%
import pandas as pd, pathlib
base = pathlib.Path().resolve().parents[0]
df = pd.read_csv(base/'data'/'people.csv')
df.head()
